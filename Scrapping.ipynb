# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
CATALOG_URL = "https://www.shl.com/solutions/products/product-catalog/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/91.0.4472.124 Safari/537.36"
}

# %%
def parse_assessment_table(table):
    """
    Extracts assessment details from an HTML table element.
    """
    results = []
    rows = table.select("tr")[1:]  # Skip the header row

    for row in rows:
        columns = row.select("td")
        if len(columns) < 4:
            continue

        # Extract name and URL
        title_tag = columns[0].find("a")
        title = title_tag.text.strip() if title_tag else "Untitled"
        link = "https://www.shl.com" + title_tag.get("href", "") if title_tag else ""

        # Remote Testing Support
        is_remote = "Yes" if columns[1].select_one(".catalogue__circle.-yes") else "No"

        # Adaptive/IRT Support
        is_adaptive = "Yes" if columns[2].select_one(".catalogue__circle.-yes") else "No"

        # Test Types
        type_tags = columns[3].select(".product-catalogue__key")
        test_types = ", ".join(tag.text.strip() for tag in type_tags) if type_tags else "N/A"

        results.append({
            "Assessment Name": title,
            "URL": link,
            "Remote Testing": is_remote,
            "Adaptive/IRT": is_adaptive,
            "Test Type": test_types,
            "Duration": "N/A"  # Duration not available from table
        })

    return results

# %%
def collect_assessments(base_url, label, query_type):
    """
    Scrapes assessment entries from paginated catalog sections.
    """
    current_url = f"{base_url}?type={query_type}"
    full_results = []

    while current_url:
        response = requests.get(current_url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Error fetching {current_url} - Status code: {response.status_code}")
            break

        soup = BeautifulSoup(response.content, "html.parser")
        print(f"📄 Processing page: {soup.title.string.strip() if soup.title else 'Untitled'}")

        relevant_table = None
        for tbl in soup.find_all("table"):
            title_cell = tbl.find("th", class_="custom__table-heading__title")
            if title_cell and label in title_cell.text:
                relevant_table = tbl
                break

        if not relevant_table:
            print(f"⚠️ Couldn't find the expected table: {label}")
            break

        items = parse_assessment_table(relevant_table)
        full_results.extend(items)

        next_page = soup.find("a", text="Next")
        if next_page and next_page.get("href"):
            current_url = "https://www.shl.com" + next_page["href"]
            print(f"➡️ Navigating to next page...\n")
            time.sleep(1)
        else:
            print("✅ No more pages to scrape.")
            current_url = None

    return full_results

# %%
def scrape_shl_data():
    """
    Runs the full scraping process for SHL Individual & Pre-packaged test solutions.
    """
    print("🚀 Starting SHL assessment scraping...")

    prebuilt_tests = collect_assessments(CATALOG_URL, "Pre-packaged Job Solutions", "2")
    individual_tests = collect_assessments(CATALOG_URL, "Individual Test Solutions", "1")

    all_tests = prebuilt_tests + individual_tests
    df = pd.DataFrame(all_tests)

    print(f"✅ Scraped {len(df)} total assessments.")
    return df

# %%
def export_results(df, filename="shl_assesment_results.csv"):
    """
    Saves results to a CSV file.
    """
    if df.empty:
        print("⚠️ No data found to export.")
    else:
        df.to_csv(filename, index=False)
        print(f"📁 Data saved to {filename}")

if __name__ == "__main__":
    data_frame = scrape_shl_data()
    export_results(data_frame)
# Out:
# 🚀 Starting SHL assessment scraping...
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
# <ipython-input-4-a7abdb89f5fa>:31: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   next_page = soup.find("a", text="Next")
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ➡️ Navigating to next page...
#
# 📄 Processing page: Talent Assessments Catalog | SHL
# ✅ No more pages to scrape.
# 📄 Processing page: Talent Assessments Catalog | SHL
# ⚠️ Couldn't find the expected table: Individual Test Solutions
# ✅ Scraped 141 total assessments.
# 📁 Data saved to shl_assesment_results.csv

# %%
# prompt: load shl_catalog_result csv as dataframe

import pandas as pd

# Assuming the CSV file is in the current working directory or provide the full path
df = pd.read_csv('/content/shl_assesment_results.csv')
print(df.head()) # Display first few rows to verify
# Out:
#                             Assessment Name  \
# 0                  Account Manager Solution
# 1  Administrative Professional - Short Form
# 2                   Agency Manager Solution
# 3   Apprentice + 8.0 Job Focused Assessment
# 4     Apprentice 8.0 Job Focused Assessment
#
#                                                  URL Remote Testing  \
# 0  https://www.shl.com/solutions/products/product...            Yes
# 1  https://www.shl.com/solutions/products/product...            Yes
# 2  https://www.shl.com/solutions/products/product...            Yes
# 3  https://www.shl.com/solutions/products/product...            Yes
# 4  https://www.shl.com/solutions/products/product...            Yes
#
#   Adaptive/IRT   Test Type  Duration
# 0          Yes  C, P, A, B       NaN
# 1          Yes     A, K, P       NaN
# 2          Yes  A, B, P, S       NaN
# 3           No        B, P       NaN
# 4           No        B, P       NaN

# %%
# Find duplicate rows based on all columns
duplicate_rows = df[df.duplicated(keep=False)]

# Sort the DataFrame to group duplicates together
duplicate_rows = duplicate_rows.sort_values(by=list(df.columns))

duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Assessment Name, URL, Remote Testing, Adaptive/IRT, Test Type, Duration]
# Index: []

# %%
df.columns
# Out:
# Index(['Assessment Name', 'URL', 'Remote Testing', 'Adaptive/IRT', 'Test Type',
#        'Duration'],
#       dtype='object')

# %%
import time

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/91.0.4472.124 Safari/537.36"
}

def get_detail_data(url):
    try:
        response = requests.get(url, headers=HEADERS, timeout=20)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")

        def extract_section_by_heading(heading):
            divs = soup.find_all("div", class_="product-catalogue-training-calendar__row")
            for div in divs:
                h4 = div.find("h4")
                if h4 and h4.text.strip() == heading:
                    p = div.find("p")
                    return p.get_text(strip=True) if p else "N/A"
            return "N/A"

        description = extract_section_by_heading("Description")
        job_levels = extract_section_by_heading("Job levels")
        languages = extract_section_by_heading("Languages")
        assessment_length = extract_section_by_heading("Assessment length")

        return description, job_levels, languages, assessment_length

    except Exception as e:
        print(f"⚠️ Error fetching {url}: {e}")
        return "N/A", "N/A", "N/A", "N/A"


def enrich_with_details(csv_path, output_path="/content/shl_assesment_results_final.csv"):
    df = pd.read_csv(csv_path)

    # Create empty new columns
    df["description"] = ""
    df["job_levels"] = ""
    df["languages"] = ""
    df["assessment_length"] = ""

    for i, row in df.iterrows():
        print(f"🔎 Scraping {i+1}/{len(df)}: {row['Assessment Name']}")
        desc, levels, langs, length = get_detail_data(row["URL"])
        df.at[i, "description"] = desc
        df.at[i, "job_levels"] = levels
        df.at[i, "languages"] = langs
        df.at[i, "assessment_length"] = length

        # Sleep a bit to avoid hammering the server
        time.sleep(1)

    df.to_csv(output_path, index=False)
    print(f"✅ Enriched data saved to {output_path}")

if __name__ == "__main__":
    # Adjust filename to your CSV file
    enrich_with_details("/content/shl_assesment_results.csv")
# Out:
# 🔎 Scraping 1/141: Account Manager Solution
# 🔎 Scraping 2/141: Administrative Professional - Short Form
# 🔎 Scraping 3/141: Agency Manager Solution
# 🔎 Scraping 4/141: Apprentice + 8.0 Job Focused Assessment
# 🔎 Scraping 5/141: Apprentice 8.0 Job Focused Assessment
# 🔎 Scraping 6/141: Bank Administrative Assistant - Short Form
# 🔎 Scraping 7/141: Bank Collections Agent - Short Form
# 🔎 Scraping 8/141: Bank Operations Supervisor - Short Form
# 🔎 Scraping 9/141: Bilingual Spanish Reservation Agent Solution
# 🔎 Scraping 10/141: Bookkeeping, Accounting, Auditing Clerk Short Form
# 🔎 Scraping 11/141: Branch Manager - Short Form
# 🔎 Scraping 12/141: Cashier Solution
# 🔎 Scraping 13/141: Claims/Operations Supervisor Solution
# 🔎 Scraping 14/141: Contact Center Customer Service + 8.0
# 🔎 Scraping 15/141: Contact Center Customer Service 8.0
# 🔎 Scraping 16/141: Contact Center Manager - Short Form
# 🔎 Scraping 17/141: Contact Center Sales & Service + 8.0
# 🔎 Scraping 18/141: Contact Center Sales & Service 8.0
# 🔎 Scraping 19/141: Contact Center Team Lead/Coach - Short Form
# 🔎 Scraping 20/141: Contact Centre Agent Solution - UK
# 🔎 Scraping 21/141: Customer Service - Short Form
# 🔎 Scraping 22/141: Customer Service - Short Form - UK
# 🔎 Scraping 23/141: Customer Service with Sales - Short Form
# 🔎 Scraping 24/141: Director - Short Form
# 🔎 Scraping 25/141: District/Regional Manager Solution
# 🔎 Scraping 26/141: Entry Level Cashier 7.1 (Americas)
# 🔎 Scraping 27/141: Entry Level Cashier 7.1 (International)
# 🔎 Scraping 28/141: Entry Level Customer Service 7.1 (Americas)
# 🔎 Scraping 29/141: Entry Level Customer Service 7.1 (International)
# 🔎 Scraping 30/141: Entry Level Customer Service 7.1 (South Africa)
# 🔎 Scraping 31/141: Entry level Sales 7.1 (Americas)
# 🔎 Scraping 32/141: Entry level Sales 7.1 (International)
# 🔎 Scraping 33/141: Entry Level Sales Sift Out 7.1
# 🔎 Scraping 34/141: Event Sales Manager Solution
# 🔎 Scraping 35/141: Executive - Short Form
# 🔎 Scraping 36/141: Financial Professional - Short Form
# 🔎 Scraping 37/141: Financial Services Representative Solution
# 🔎 Scraping 38/141: Front Desk Associate Solution
# 🔎 Scraping 39/141: Gaming Associate Solution
# 🔎 Scraping 40/141: Gaming Manager Solution
# 🔎 Scraping 41/141: General Entry Level - All Industries 7.0 Solution
# 🔎 Scraping 42/141: General Entry Level - All Industries 7.1 Solution
# 🔎 Scraping 43/141: General Entry Level - All Industries 7.1(Americas)
# 🔎 Scraping 44/141: General Entry Level – Data Entry 7.0 Solution
# 🔎 Scraping 45/141: Graduate + 8.0 Job Focused Assessment
# 🔎 Scraping 46/141: Graduate 7.1 Job Focused Assessment
# 🔎 Scraping 47/141: Graduate 8.0 Job Focused Assessment
# 🔎 Scraping 48/141: Guest Service Team 7.0 Solution
# 🔎 Scraping 49/141: Guest Services Associate Solution
# 🔎 Scraping 50/141: Healthcare Aide 7.0 Solution
# 🔎 Scraping 51/141: Healthcare Call Center Agent Solution
# 🔎 Scraping 52/141: Healthcare Service Associate Solution
# 🔎 Scraping 53/141: Healthcare Support Specialist Solution
# 🔎 Scraping 54/141: Home Health Aide Solution
# 🔎 Scraping 55/141: Hospitality Manager Solution
# 🔎 Scraping 56/141: Host Solution
# 🔎 Scraping 57/141: Industrial - Entry Level 7.0 Solution
# 🔎 Scraping 58/141: Industrial - Entry Level 7.1 (Americas)
# 🔎 Scraping 59/141: Industrial - Entry Level 7.1 (International)
# 🔎 Scraping 60/141: Industrial - Professional and Skilled 7.0 Solution
# 🔎 Scraping 61/141: Industrial - Semi-skilled 7.1 (Americas)
# 🔎 Scraping 62/141: Industrial - Semi-skilled 7.1 (International)
# 🔎 Scraping 63/141: Industrial Professional and Skilled 7.1 (Americas)
# 🔎 Scraping 64/141: Industrial Professional and Skilled 7.1 Solution
# 🔎 Scraping 65/141: Installation and Repair Technician Solution
# 🔎 Scraping 66/141: Insurance Account Manager Solution
# 🔎 Scraping 67/141: Insurance Administrative Assistant Solution
# 🔎 Scraping 68/141: Insurance Agent Solution
# 🔎 Scraping 69/141: Insurance Director Solution
# 🔎 Scraping 70/141: Insurance Sales Manager Solution
# 🔎 Scraping 71/141: Manager - Short Form
# 🔎 Scraping 72/141: Manager + 7.0 Solution
# 🔎 Scraping 73/141: Manager + 7.1 (Americas)
# 🔎 Scraping 74/141: Manager + 7.1 (International)
# 🔎 Scraping 75/141: Manager 7.0 Solution
# 🔎 Scraping 76/141: Manager 7.1 (Americas)
# 🔎 Scraping 77/141: Manager 7.1 (International)
# 🔎 Scraping 78/141: Manager 8.0 JFA
# 🔎 Scraping 79/141: Manager 8.0+ JFA
# 🔎 Scraping 80/141: Manufacturing Production Team Member
# 🔎 Scraping 81/141: Manufacturing Skilled Maintenance Worker
# 🔎 Scraping 82/141: Network Engineer/Analyst Solution
# 🔎 Scraping 83/141: Nurse Leader Solution
# 🔎 Scraping 84/141: Nurse Solution
# 🔎 Scraping 85/141: Nursing Assistant Solution
# 🔎 Scraping 86/141: Personal Banker - Short Form
# 🔎 Scraping 87/141: Phone Banker - Short Form
# 🔎 Scraping 88/141: Prep/Line Cook Solution
# 🔎 Scraping 89/141: Professional + 7.0 Solution
# 🔎 Scraping 90/141: Professional + 7.1 (Americas)
# 🔎 Scraping 91/141: Professional + 7.1 (International)
# 🔎 Scraping 92/141: Professional 7.0 Solution
# 🔎 Scraping 93/141: Professional 7.1 (International)
# 🔎 Scraping 94/141: Professional 8.0 JFA
# 🔎 Scraping 95/141: Professional/Individual Contributor - Short Form
# 🔎 Scraping 96/141: Project Manager - Short Form
# 🔎 Scraping 97/141: Proof Operator - Processing Specialist -Short Form
# 🔎 Scraping 98/141: Reservation Agent Solution
# 🔎 Scraping 99/141: Restaurant Manager Solution
# 🔎 Scraping 100/141: Restaurant Supervisor Solution
# 🔎 Scraping 101/141: Retail Consultant Solution
# 🔎 Scraping 102/141: Retail Manager w/ Sales Solution
# 🔎 Scraping 103/141: Retail Sales Associate Solution
# 🔎 Scraping 104/141: Sales Director Solution
# 🔎 Scraping 105/141: Sales Engineer Solution
# 🔎 Scraping 106/141: Sales Manager Solution
# 🔎 Scraping 107/141: Sales Professional 7.0 Solution
# 🔎 Scraping 108/141: Sales Professional 7.1 (Americas)
# 🔎 Scraping 109/141: Sales Professional Solution
# 🔎 Scraping 110/141: Sales Representative Solution
# 🔎 Scraping 111/141: Sales Supervisor Solution
# 🔎 Scraping 112/141: Sales Support Specialist Solution
# 🔎 Scraping 113/141: Senior Insurance Agent Solution
# 🔎 Scraping 114/141: Senior Sales Professional Solution
# 🔎 Scraping 115/141: Server Solution
# 🔎 Scraping 116/141: Service Associate Solution
# 🔎 Scraping 117/141: Service Supervisor Solution
# 🔎 Scraping 118/141: Stock Clerk Solution
# 🔎 Scraping 119/141: Store Manager 7.0 Solution
# 🔎 Scraping 120/141: Store Manager 7.1 (Americas)
# 🔎 Scraping 121/141: Store Manager 7.1 (International)
# 🔎 Scraping 122/141: Store Manager Solution
# 🔎 Scraping 123/141: Supervisor - Short Form
# 🔎 Scraping 124/141: Supervisor 7.0 Solution
# 🔎 Scraping 125/141: Supervisor 7.1 (Americas)
# 🔎 Scraping 126/141: Supervisor 7.1 (International)
# 🔎 Scraping 127/141: Support Associate Solution
# 🔎 Scraping 128/141: Support Supervisor Solution
# 🔎 Scraping 129/141: Technical Sales Associate Solution
# 🔎 Scraping 130/141: Technician/Technologist Solution
# 🔎 Scraping 131/141: Technology Professional 8.0 Job Focused Assessment
# 🔎 Scraping 132/141: Telenurse Solution
# 🔎 Scraping 133/141: Teller 7.0
# 🔎 Scraping 134/141: Teller with Sales - Short Form
# 🔎 Scraping 135/141: Transcriptionist Solution
# 🔎 Scraping 136/141: Workplace Safety - Individual 7.0 Solution
# 🔎 Scraping 137/141: Workplace Safety - Individual 7.1 (Americas)
# 🔎 Scraping 138/141: Workplace Safety - Team 7.0 Solution
# 🔎 Scraping 139/141: Workplace Safety - Team 7.1 (Americas)
# 🔎 Scraping 140/141: Workplace Safety - Team 7.1 (International)
# 🔎 Scraping 141/141: Workplace Safety Solution
# ✅ Enriched data saved to /content/shl_assesment_results_final.csv
